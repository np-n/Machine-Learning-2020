# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten,Dense,BatchNormalization,Conv2D,MaxPool2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image
print(tf.__version__)
# Out:
# 2.3.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %% [markdown]
# Dataset link
# https://www.cs.ccu.edu.tw/~wtchu/projects/MoviePoster/index.html

# %%
# Cloning movies poster datasets
# !git clone https://github.com/laxmimerit/Movies-Poster_Dataset.git
# Out:
# Cloning into 'Movies-Poster_Dataset'...
# remote: Enumerating objects: 7873, done.
# remote: Total 7873 (delta 0), reused 0 (delta 0), pack-reused 7873
# Receiving objects: 100% (7873/7873), 246.59 MiB | 11.95 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Checking out files: 100% (7871/7871), done.

# %%
# Check your files , coloned data are placed into file directory

# %%
# Reading .csv file where all image address are presented as ID and description are given
data = pd.read_csv('/content/Movies-Poster_Dataset/train.csv')
data.head()
# Out:
#           Id                                Genre  ...  War  Western
# 0  tt0086425                  ['Comedy', 'Drama']  ...    0        0
# 1  tt0085549        ['Drama', 'Romance', 'Music']  ...    0        0
# 2  tt0086465                           ['Comedy']  ...    0        0
# 3  tt0086567               ['Sci-Fi', 'Thriller']  ...    0        0
# 4  tt0086034  ['Action', 'Adventure', 'Thriller']  ...    0        0
#
# [5 rows x 27 columns]

# %%
# Not all image have information in the data file
data.shape[0]
# Out:
# 7254

# %%
# To convert image into similar size
# let define height and width 
img_width = 350
img_height =350

# creating empty array to add image
x = []

for i in tqdm(range(data.shape[0])):
  # Getting path of all image
  path = '/content/Movies-Poster_Dataset/Images/'+ data['Id'][i] + '.jpg'
  # loading all image in img shaping by target_size
  img = image.load_img(path,target_size=(img_width,img_height))
  # To compute over images we are converting images to pixel matrix
  img = image.img_to_array(img)
  # Neural networks perform well on the normalized image
  img = img/255.0

  # Appending all normalized image (matrix ) into  multidimensional array
  x.append(img)

# Converting array to numpy array
x = np.array(x)
# Out:
# 100%|██████████| 7254/7254 [00:28<00:00, 254.39it/s]

# %%
x.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9f2b259887ef> in <module>()
# ----> 1 x.shape
#
# NameError: name 'x' is not defined

# %%
# While running above cell kernel is crashed and need to increase RAM from 12 to 25 GB

# %%
a
