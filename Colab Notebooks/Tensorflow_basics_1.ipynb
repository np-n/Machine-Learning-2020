# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.3.0'

# %%
hello = tf.constant("Hello")

# %%
world = tf.constant("World")

# %%
type(hello)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
print(hello)
# Out:
# tf.Tensor(b'Hello', shape=(), dtype=string)

# %%
with tf.Session() as sess:
  sess.run(hello+world)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-00e547933f01> in <module>()
# ----> 1 with tf.Session() as sess:
#       2   sess.run(hello+world)
#
# AttributeError: module 'tensorflow' has no attribute 'Session'

# %%
# To avoid error 
# In new version of tensorflow

tf.print(hello+world)
# Out:
# HelloWorld

# %%
a =tf.constant([2])
b= tf.constant([3])

# %%
a
# Out:
# <tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>

# %%
c = tf.add(a,b)

# %%
# with tf.Session() as session:
#   session.run(c)

# Solution
tf.print(c)
# Out:
# [5]

# %%
tf.print(a)
# Out:
# [2]

# %%
tf.print(b)
# Out:
# [3]

# %%
mat = tf.constant([[1,2,3],[2,3,4]])

# %%
tf.print(mat)
# Out:
# [[1 2 3]
#  [2 3 4]]

# %%
mat1 = tf.constant([[1, 2, 3],[2, 3, 4],[2, 5, 6],[4, 5, 6]])

# %%
tf.print(mat1)
# Out:
# [[1 2 3]
#  [2 3 4]
#  [2 5 6]
#  [4 5 6]]

# %%
one = tf.constant(1)
two = tf.constant(4)
tf.assign(one,two)
tf.print(new_one)
tf.print(tf.add(one,two))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-71b068c1ccac> in <module>()
#       1 one = tf.constant(1)
#       2 two = tf.constant(4)
# ----> 3 tf.assign(one,two)
#       4 tf.print(new_one)
#       5 tf.print(tf.add(one,two))
#
# AttributeError: module 'tensorflow' has no attribute 'assign'

# %%
|
